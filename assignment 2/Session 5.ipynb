# %% [raw]
# Tasks
# 1. Create a list called playlist_ids with 5 song IDs (as integers) that you might see in a Spotify playlist, and print the list.
# 2. Add two more song IDs to your playlist_ids list using both append() and extend(), then print the updated list.
# Hint: Use append() for a single ID and extend() for adding multiple IDs at once.
# 3. Simulate removing the last played song from your playlist_ids list using pop(), and display the removed ID along with the remaining playlist.
# 4. Create a tuple called insta_filters with 4 Instagram filter names (as strings). Try to change the first filter name and observe what error you get.
# Hint: Tuples are immutable. Note down the error message.
# 5. Write a short Python script that takes a scenario (like a list of recent Zomato orders vs a tuple of fixed IPL team names) and prints which one should use a list and which should use a tuple, explaining your choice in a comment.

# %%
playlist_ids = [101, 102, 103, 104, 105]

print(playlist_ids)
# Out:
# [101, 102, 103, 104, 105]

# %%
playlist_ids = [101, 102, 103, 104, 105]

playlist_ids.append(106)          # Add one song ID
playlist_ids.extend([107, 108])   # Add multiple song IDs

print(playlist_ids)
# Out:
# [101, 102, 103, 104, 105, 106, 107, 108]

# %%
playlist_ids = [101, 102, 103, 104, 105, 106, 107, 108]

removed_song = playlist_ids.pop()

print("Removed Song ID:", removed_song)
print("Remaining Playlist:", playlist_ids)
# Out:
# Removed Song ID: 108
# Remaining Playlist: [101, 102, 103, 104, 105, 106, 107]

# %%
insta_filters = ("Clarendon", "Juno", "Lark", "Valencia")

insta_filters[0] = "Gingham"

print(insta_filters)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 insta_filters = ("Clarendon", "Juno", "Lark", "Valencia")
# ----> 3 insta_filters[0] = "Gingham"
#       5 print(insta_filters)
#
# TypeError: 'tuple' object does not support item assignment

# %%
# Recent Zomato orders can change frequently, so a list is suitable.
zomato_orders = ["Pizza", "Burger", "Pasta"]

# IPL team names are fixed, so a tuple is suitable.
ipl_teams = (
    "Mumbai Indians",
    "Chennai Super Kings",
    "Royal Challengers Bengaluru"
)

print("Zomato Orders (List):", zomato_orders)
print("IPL Teams (Tuple):", ipl_teams)
# Out:
# Zomato Orders (List): ['Pizza', 'Burger', 'Pasta']
# IPL Teams (Tuple): ('Mumbai Indians', 'Chennai Super Kings', 'Royal Challengers Bengaluru')
