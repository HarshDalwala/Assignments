# %% [raw]
# Tasks
# 1. Create a Python dictionary called insta_followers that stores the number of followers for 5 Instagram influencers (use their usernames as keys and follower counts as values). Print the dictionary.
# 2. Add a new influencer to your insta_followers dictionary and update the follower count for one existing influencer. Then, delete one influencer from the dictionary and print the updated dictionary.
# 3. Given a dictionary called food_prices with 5 Zomato food items as keys and their prices as values, write code to display all items that cost more than ₹200.
# 4. Create two sets: flipkart_users and myntra_users, each containing 5 unique usernames. Find and print the set of users who have accounts on both platforms using set intersection.
# 5. Write a function get_unique_artists(spotify_playlist1, spotify_playlist2) that takes two sets of artist names and returns a set of all unique artists across both playlists (set union).
#
# Hint: Use the union() method or the | operator for sets.

# %%
insta_followers = {
    "virat18": 270000000,
    "shraddhakapoor": 95000000,
    "aliaabhatt": 86000000,
    "deepikapadukone": 80000000,
    "narendramodi": 95000000
}

print(insta_followers)
# Out:
# {'virat18': 270000000, 'shraddhakapoor': 95000000, 'aliaabhatt': 86000000, 'deepikapadukone': 80000000, 'narendramodi': 95000000}

# %%
insta_followers = {
    "virat18": 270000000,
    "shraddhakapoor": 95000000,
    "aliaabhatt": 86000000,
    "deepikapadukone": 80000000,
    "narendramodi": 95000000
}

# Add a new influencer
insta_followers["techburner"] = 5000000

# Update follower count
insta_followers["aliaabhatt"] = 87000000

# Delete an influencer
del insta_followers["deepikapadukone"]

print(insta_followers)
# Out:
# {'virat18': 270000000, 'shraddhakapoor': 95000000, 'aliaabhatt': 87000000, 'narendramodi': 95000000, 'techburner': 5000000}

# %%
food_prices = {
    "Pizza": 299,
    "Burger": 149,
    "Biryani": 250,
    "Pasta": 220,
    "Sandwich": 120
}

for item, price in food_prices.items():
    if price > 200:
        print(item, ":", price)
# Out:
# Pizza : 299
# Biryani : 250
# Pasta : 220

# %%
flipkart_users = {"harsh", "amit", "rahul", "priya", "neha"}
myntra_users = {"rahul", "neha", "karan", "pooja", "harsh"}

common_users = flipkart_users.intersection(myntra_users)

print("Users on both platforms:", common_users)
# Out:
# Users on both platforms: {'rahul', 'neha', 'harsh'}

# %%
def get_unique_artists(spotify_playlist1, spotify_playlist2):
    return spotify_playlist1.union(spotify_playlist2)

playlist1 = {"Arijit Singh", "Shreya Ghoshal", "Atif Aslam"}
playlist2 = {"Arijit Singh", "Neha Kakkar", "Sonu Nigam"}

print(get_unique_artists(playlist1, playlist2))
# Out:
# {'Sonu Nigam', 'Shreya Ghoshal', 'Atif Aslam', 'Arijit Singh', 'Neha Kakkar'}
